# %% [markdown]
# # 1. 순차 탐색 Sequential Search

# %% [markdown]
# * 탐색은 여러 데이터 중에서 원하는 데이터를 찾아내는 것을 의미
# * 데이터가 담겨있는 리스트를 앞에서부터 하나씩 비교해서 원하는 데이터를 찾는 방법

# %%
from random import *

seed(435)
rand_data_list = list()
for num in range(10):
  rand_data_list.append(randint(1,100))

rand_data_list
# Out:
# [25, 67, 63, 40, 7, 73, 79, 89, 90, 62]

# %%
def sequential(data_list, search_data):
  for i in range(len(data_list)):
    if data_list[i] == search_data:
      return data_list[i]
  return -1

# %%
sequential(rand_data_list, 89), sequential(rand_data_list, 62), sequential(rand_data_list, 5)
# Out:
# (89, 62, -1)

# %% [markdown]
# # 2. 알고리즘 분석

# %% [markdown]
# * 최악의 경우 리스트의 길이가 n일때 n번 비교해야함
# * big o 표기법에 의하면 O(n)임
