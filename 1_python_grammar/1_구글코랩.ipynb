# %% [markdown]
# #1. 코랩의 성능

# %% [markdown]
# ###1-1. OS 환경

# %%
# !cat /etc/issue.net
# Out:
# Ubuntu 18.04.5 LTS

# %% [markdown]
# ###1-2. Python 버전

# %%
# !python --version
# Out:
# Python 3.7.13

# %% [markdown]
# #2. 셀의 종류

# %% [markdown]
# * 코드 : 파이선 코드를 실행할 수 있는 셀
# * 텍스트 : 설명을 달거나 문구등을 적기 위한 텍스트 전용 셀 (마크 다운)

# %% [markdown]
# ###2-1. 셀의 삽입 방법
# 1. 상단의 "+코드", "+텍스트" 버튼을 눌러 삽입
# 2. 코드셀을 위에 삽입 : 컨트롤 + M,A
# 3. 코드셀을 아래에 삽입 : 컨트롤 + M,B

# %% [markdown]
# ###2-2. 셀을 변경하는 방법
# 1. 코드셀을 텍스트셀로 변경 : 컨트롤 + M,M
# 2. 텍스트셀을 코드셀로 변경 : 컨트롤 + M,Y

# %% [markdown]
# ###2-3. 셀을 삭제하는 방법
# 1. 우측의 휴지통 아이콘 클릭
# 2. 컨트롤 + M,D

# %% [markdown]
# ###2-4. 단축키 설정하는 방법
# 1. 컨트롤 + M,H

# %% [markdown]
# #3. 셀의 실행

# %% [markdown]
# * 컨트롤 + 엔터 : 해당 셀 실행 후 커서는 해당 셀에 남음
# * 쉬프트 + 엔터 : 해당 셀 실행 후 커서는 다음셀로 넘어감 (뒤에 셀이 있을 경우 다음 셀로 넘어가고, 없을 경우 실행 후 다음 셀을 만듬)
# * 알트 + 엔터 : 해달 셀을 실행하고 커서는 다음셀로 삽입하고 넘어감 (무조건 다음셀을 만듬)

# %% [markdown]
# print('안녕하세요')

# %% [markdown]
# #4. 이미지 다루기

# %%
from IPython.display import Image

# %%
Image('https://t1.daumcdn.net/daumtop_chanel/op/20200723055344399.png')

# %% [markdown]
# #5. 유투브 동영상 로딩하기

# %%
from IPython.display import YouTubeVideo

# %%
YouTubeVideo('-UVXrGUbw-A', width=400, height=300)

# %% [markdown]
# #6. 파일 다루기

# %% [markdown]
# ###6-1. 파일 직접 올리기
# 1. files.upload() 함수 사용
# 2. 메뉴 - 파일 - 드래그앤드랍

# %%
from google.colab import files

# %%
myfile = files.upload()
# Out:
#      <input type="file" id="files-04c5fe4a-0cc1-459a-8bcc-f6158948b99f" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-04c5fe4a-0cc1-459a-8bcc-f6158948b99f">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving User Story Board_ver 1.0.0.5_210812.pdf to User Story Board_ver 1.0.0.5_210812.pdf

# %% [markdown]
# ###6-2. 구글 드라이브에서 파일 가져오기 (안 사라지는 것)

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
